# %% [markdown]
# <a href="https://colab.research.google.com/github/MAB1144-Python/python-ejercicios/blob/master/modelo_cambiar_temperatura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from google.colab import drive
drive.mount('/gdrive')
import glob

print ("Leyendo CSV")
temperature_df = pd.read_csv("/gdrive/My Drive/Colab_Notebooks/celsius_a_fahrenheit.csv")
 
# Visualización

sns.scatterplot(x=temperature_df['Celsius'], y=temperature_df['Fahrenheit'])
plt.show()

#Cargando Set de Datos
print ("Seleccionando las columnas")
X_train = temperature_df['Celsius']
y_train = temperature_df['Fahrenheit']
print ("Creando el modelo")
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=1, input_shape=[1]))
print ("Compilando el modelo")
model.compile(optimizer=tf.keras.optimizers.Adam(1), loss='mean_squared_error')

#Entrenando el modelo
print ("Entrenando el modelo")
epochs_hist = model.fit(X_train, y_train, epochs = 100)

#Evaluando modelo
print ("Evaluando el modelo entrenado")
print ("Keys:")
print(epochs_hist.history.keys())
	
#Grafico

plt.plot(epochs_hist.history['loss'])

plt.title('Progreso de Pérdida durante Entrenamiento del Modelo')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.legend('Training Loss')
plt.show()

Temp_C = 0
Temp_F = model.predict([Temp_C])
print("Temperatura de Prediccion: " + str(Temp_F))

Temp_F = 9/5 * Temp_C + 32
print("Temperatura de Ecuacion: " + str(Temp_F))
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# Leyendo CSV
# Seleccionando las columnas
# Creando el modelo
# Compilando el modelo
# Entrenando el modelo
# Epoch 1/100
# 1/1 [==============================] - 1s 654ms/step - loss: 2329.3232
# Epoch 2/100
# 1/1 [==============================] - 0s 6ms/step - loss: 1140.1362
# Epoch 3/100
# 1/1 [==============================] - 0s 7ms/step - loss: 934.3929
# Epoch 4/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1212.0411
# Epoch 5/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1316.3850
# Epoch 6/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1136.3190
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 856.9329
# Epoch 8/100
# 1/1 [==============================] - 0s 10ms/step - loss: 650.5465
# Epoch 9/100
# 1/1 [==============================] - 0s 9ms/step - loss: 590.3665
# ...
